# %% [markdown]
# # Describing Distributions (Core)
# ## The features to analyze:
# * VitD_levels
# * Doc_visits
# * TotalCharge
# * For each feature listed:
#
# 1. Plot a histogram with a kde (kernel density estimate)
# * Add a line for the mean (red)
# * Add a line for the median (green)
# * Add a line for for +1 std from the mean (black)
# * Add a line for the - 1 std from the mean (black)
# * Highlight the range between +1 and =1 std (yellow)
# 2. Answer the following questions:
# * Is it Discrete or Continuous?
# * Does it have a skew? If so, which direction (+/-)
# * What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from scipy import stats
plt.style.use(['seaborn-muted','fivethirtyeight'])
sns.set_context('talk')

# %%
df = pd.read_csv('medical_dataset.csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# ## Plot a histogram with a kde (kernel density estimate) for Vitamin D Levels

# %%
#Plot histogram of KDE for VtiD Levels with listed criterias
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x='VitD_levels', discrete=True, stat='density', kde = True);
ax.axvline(mean, color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
#Check value counts to find out if distribution is discrete or continuous
df['VitD_levels'].value_counts()
# Out:
# 19.141466    1
# 18.180901    1
# 21.097365    1
# 18.670625    1
# 18.988771    1
#             ..
# 13.306814    1
# 16.019013    1
# 14.088522    1
# 15.801872    1
# 19.487658    1
# Name: VitD_levels, Length: 1000, dtype: int64

# %%
#Calculate kurtosis stats
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# * The vitamin D levels is a continuous data because it can be measured
# * Chart shows distribution to be normal with no skew
# * According to the kurtosis stats, the distribution displays Mesokurtic to be the kurtosis which is normal

# %% [markdown]
# ## Plot a histogram with a kde (kernel density estimate) for Doctor Visits

# %%
#Plot histogram of KDE for Doc visits with listed criterias
col2 = 'Doc_visits'
feature = df[col2]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x='Doc_visits', discrete=True, stat='density', kde = True);
ax.axvline(mean, color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col2}')
ax.legend();

# %%
#Check value counts to find out if distribution is discrete or continuous
df['Doc_visits'].value_counts()
# Out:
# 5    394
# 4    232
# 6    229
# 3     69
# 7     66
# 2      5
# 8      4
# 9      1
# Name: Doc_visits, dtype: int64

# %%
#Calculate kurtosis stats
kurt2 = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt2
# Out:
# 2.9919958083381206

# %% [markdown]
# * The doctor visits is a discrete data because it is specific numbers
# * Chart shows distribution to be normal with no skew
# * According to the kurtosis stats, the distribution displays Platykurtic to be the kurtosis which is negative or flat distribution

# %% [markdown]
# ## Plot a histogram with a kde (kernel density estimate) for Total Charge

# %%
#Plot histogram of KDE for Total Charge with listed criterias
col3 = 'TotalCharge'
feature = df[col3]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x='TotalCharge', discrete=True, stat='density', kde = True);
ax.axvline(mean, color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col3}')
ax.legend();

# %%
#Check value counts to find out if distribution is discrete or continuous
df['TotalCharge'].value_counts()
# Out:
# 3726.702860    1
# 3519.071379    1
# 2916.906301    1
# 3241.796541    1
# 2730.309350    1
#               ..
# 3283.523074    1
# 3701.824248    1
# 3680.545305    1
# 3496.001774    1
# 2830.020820    1
# Name: TotalCharge, Length: 1000, dtype: int64

# %% [markdown]
# Positively skewed

# %%
#Calculate kurtosis stats
kurt3 = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt3
# Out:
# 3.2650077463439384

# %% [markdown]
# * The total charge is a continuous data because it can be measured and changes frequently
# * Chart shows distribution to be positive with skew to the left
# * According to the kurtosis stats, the distribution displays Leptokurtic to be the kurtosis which is positive because the stats shows to be greater than 3
